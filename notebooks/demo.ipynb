# %% [markdown]
# # BioGeoDA NLP Pipeline Demo
#
# This notebook uses only synthetic sample data from this repository.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from preprocess import clean_text
from propagation_rules import load_propagation_keywords, extract_propagation_methods

sentence = 'Seeds benefit from soaking before sowing.'
keywords = load_propagation_keywords(PROJECT_ROOT / 'configs' / 'propagation_keywords.yaml')
clean_text(sentence), extract_propagation_methods(sentence, keywords)
